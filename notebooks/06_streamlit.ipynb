# %% [markdown]
# ## 06. Streamlit Interface — RAG for Migrant Parents
#
# This notebook launches the Streamlit application defined in `app/streamlit_app.py`.
# The app provides a browser-based interface for the cross-lingual RAG pipeline.
# All pipeline logic (embedding, retrieval, generation) is contained in the app file.

# %%
# Check Streamlit installation
import subprocess
result = subprocess.run(["pip", "show", "streamlit"], capture_output=True, text=True)
print(result.stdout if result.stdout else "Streamlit not installed")
# Out:
# Name: streamlit
# Version: 1.57.0
# Summary: A faster way to build and share data apps
# Home-page: https://streamlit.io
# Author:
# Author-email: Snowflake Inc <hello@streamlit.io>
# License-Expression: Apache-2.0
# Location: /Users/Olga 1/Documents/01_AD_ASTRA/0102_LANGUAGES/CAS_NLP_2025/final_project/venv_rag/lib/python3.12/site-packages
# Requires: altair, anyio, blinker, cachetools, click, gitpython, httptools, itsdangerous, numpy, packaging, pandas, pillow, protobuf, pyarrow, pydeck, python-multipart, requests, starlette, tenacity, toml, typing-extensions, uvicorn, websockets
# Required-by:

# %%
# Launch the Streamlit app from a terminal (not from this notebook).
#
# Local version (Ollama, qwen3:8b):
#   streamlit run app/streamlit_app.py
#
# Production version (UniBE GPUStack, gpt-oss-120b):
#   streamlit run app/streamlit_app_gpu.py
#
# Both versions share the same retrieval pipeline (ChromaDB,
# paraphrase-multilingual-MiniLM-L12-v2) — only the generation
# backend differs.

print("Local version:      streamlit run app/streamlit_app.py")
print("Production version: streamlit run app/streamlit_app_gpu.py")
# Out:
# Local version:      streamlit run app/streamlit_app.py
# Production version: streamlit run app/streamlit_app_gpu.py
